# %%
import pandas as pd
import re
import operator

# %%
def fn_clean_data(s):
    s = s.lower() # making everything lower case
    s = re.sub('''[(),.!?:;\"'-]''', '', s)  # remove special characters
    s = re.sub(' +', ' ', s) # remove multiple spaces
    return s

def fn_getData():
    # Reading the data-
    reference_df = pd.read_csv('reference.csv')
    query_df = pd.read_csv('query.csv')
    query_df_orig = query_df
    
    # Concatenating the relevant columns-
    reference_df['ref_name'] = reference_df.apply(lambda x:'%s%s%s%s' % (x['name'],x['address'],x['city'],x['cuisine']),axis=1)
    reference_df['ref_name'] = reference_df['ref_name'].apply(lambda x: fn_clean_data(x))
    reference_df = reference_df[['id', 'ref_name']]
    
    query_df['query_name'] = query_df.apply(lambda x:'%s%s%s%s' % (x['name'],x['address'],x['city'],x['cuisine']),axis=1)
    query_df['query_name'] = query_df['query_name'].apply(lambda x: fn_clean_data(x))
    query_df = query_df[['id', 'query_name']]
    
    return reference_df, query_df, query_df_orig

reference_df, query_df, query_df_orig = fn_getData()

# %%
def fn_getSearchTokens(row):
    search_dict = {}
    search_id = row[0]
    search_name = row[1]
    
    token_dict = {}
    for token in search_name.split(' '):
        if token not in token_dict:
            token_dict[token] = 1
    
    search_dict[search_id] = token_dict
    
    return search_dict

query_search_arr = query_df.apply(lambda row: fn_getSearchTokens(row), axis = 1).values # returns an array for query_search

reference_search_arr = reference_df.apply(lambda row: fn_getSearchTokens(row), axis = 1).values # returns an array for ref search

# %%
def fn_computeSimilarity(query_search_arr, reference_search_arr):
    score_query_dict = {}
    for query in query_search_arr:
        for query_id, query_dict in query.items():
            score_ref_dict = {}
            for reference in reference_search_arr:
                for ref_id, ref_dict in reference.items():
                    total = 0.0
                    found = 0.0
                    score = 0.0
                    for k, v in query_dict.items():
                        total += 1
                        if k in ref_dict.keys():
                            found += 1
                    score = 100*(found / total)
                    score_ref_dict[ref_id] = score
            score_query_dict[query_id] = score_ref_dict
    return score_query_dict

score_query_dict = fn_computeSimilarity(query_search_arr, reference_search_arr)

# %%
def fn_matchRefId(row, item_match_dict):
    q_id = row[0]
    ref_item_score = item_match_dict[q_id]
    return ref_item_score[0]

def fn_matchRefScore(row, item_match_dict):
    q_id = row[0]
    ref_item_score = item_match_dict[q_id]
    return round(ref_item_score[1], 2)

def fnQueryRefMap(score_query_dict, query_df_orig):
    item_match_dict = {}
    for q_id, r_dict in score_query_dict.items():
        sorted_ref_tup = sorted(r_dict.items(), key=operator.itemgetter(1), reverse=True)
        item_match_dict[q_id] = sorted_ref_tup[0] # taking the top match
        
    query_df_orig['pred_ref_id'] = query_df_orig.apply(lambda row: fn_matchRefId(row, item_match_dict), axis = 1)
    query_df_orig['pred_ref_score'] = query_df_orig.apply(lambda row: fn_matchRefScore(row, item_match_dict), axis = 1)
    
    del query_df_orig['query_name']
    
    return query_df_orig

query_df_orig = fnQueryRefMap(score_query_dict, query_df_orig)

# %%
query_df_orig
# Out:
#       id                                      name  \
# 0   1001                               chanterelle
# 1   1002                                    daniel
# 2   1003                                     dawat
# 3   1004                                   felidia
# 4   1005                              four seasons
# 5   1006                        gotham bar & grill
# 6   1007                           gramercy tavern
# 7   1008                              island spice
# 8   1009                                     jo jo
# 9   1010                              la caravelle
# 10  1011                            la cote basque
# 11  1012                              le bernardin
# 12  1013                            les celebrites
# 13  1014                lespinasse (new york city)
# 14  1015                                    lutece
# 15  1016                      manhattan ocean club
# 16  1017                                     march
# 17  1018                                mesa grill
# 18  1019                                 mi cocina
# 19  1020                                montrachet
# 20  1021                                    oceana
# 21  1022          park avenue cafe (new york city)
# 22  1023                                petrossian
# 23  1024                                 picholine
# 24  1025                                    pisces
# 25  1026                              rainbow room
# 26  1027                                river cafe
# 27  1028                              san domenico
# 28  1029                        second avenue deli
# 29  1030                                    seryna
# ..   ...                                       ...
# 52  1053                hedgerose heights inn  the
# 53  1054                            heera of india
# 54  1055                      indigo coastal grill
# 55  1056                                 la grotta
# 56  1057                       mary mac's tea room
# 57  1058                            nikolai's roof
# 58  1059                           pano's & paul's
# 59  1060              ritz-carlton cafe (buckhead)
# 60  1061       ritz-carlton dining room (buckhead)
# 61  1062                   ritz-carlton restaurant
# 62  1063                                  toulouse
# 63  1064                            veni vidi vici
# 64  1065                            alain rondelli
# 65  1066                                      aqua
# 66  1067                                 boulevard
# 67  1068                               cafe claude
# 68  1069                             campton place
# 69  1070                               chez michel
# 70  1071                              fleur de lys
# 71  1072                                  fringale
# 72  1073                            hawthorne lane
# 73  1074                      khan toke thai house
# 74  1075                                  la folie
# 75  1076                  lulu restaurant-bis-cafe
# 76  1077                                    masa's
# 77  1078                                    mifune
# 78  1079                            plumpjack cafe
# 79  1080                                   postrio
# 80  1081  ritz-carlton dining room (san francisco)
# 81  1082                              rose pistola
#
#                        address            city            cuisine  \
# 0               2 harrison st.   new york city       french (new)
# 1               20 e. 76th st.   new york city       french (new)
# 2              210 e. 58th st.   new york city             indian
# 3              243 e. 58th st.   new york city            italian
# 4               99 e. 52nd st.   new york city     american (new)
# 5               12 e. 12th st.   new york city     american (new)
# 6               42 e. 20th st.   new york city     american (new)
# 7              402 w. 44th st.   new york city          caribbean
# 8              160 e. 64th st.   new york city      french bistro
# 9               33 w. 55th st.   new york city   french (classic)
# 10              60 w. 55th st.   new york city   french (classic)
# 11             155 w. 51st st.   new york city            seafood
# 12             155 w. 58th st.   new york city   french (classic)
# 13               2 e. 55th st.   new york city              asian
# 14             249 e. 50th st.   new york city   french (classic)
# 15              57 w. 58th st.   new york city            seafood
# 16             405 e. 58th st.   new york city     american (new)
# 17              102 fifth ave.   new york city       southwestern
# 18                 57 jane st.   new york city            mexican
# 19             239 w. broadway   new york city      french bistro
# 20              55 e. 54th st.   new york city            seafood
# 21             100 e. 63rd st.   new york city     american (new)
# 22             182 w. 58th st.   new york city            russian
# 23              35 w. 64th st.   new york city      mediterranean
# 24                   95 ave. a   new york city            seafood
# 25        30 rockefeller plaza   new york city     american (new)
# 26                 1 water st.        brooklyn     american (new)
# 27         240 central park s.   new york city            italian
# 28             156 second ave.   new york city              delis
# 29              11 e. 53rd st.   new york city           japanese
# ..                         ...             ...                ...
# 52   490 e. paces ferry rd. ne         atlanta        continental
# 53           595 piedmont ave.         atlanta             indian
# 54       1397 n. highland ave.         atlanta           eclectic
# 55       2637 peachtree rd. ne         atlanta            italian
# 56      224 ponce de leon ave.         atlanta      southern/soul
# 57           255 courtland st.         atlanta        continental
# 58     1232 w. paces ferry rd.         atlanta     american (new)
# 59       3434 peachtree rd. ne         atlanta     american (new)
# 60       3434 peachtree rd. ne         atlanta     american (new)
# 61           181 peachtree st.         atlanta   french (classic)
# 62         293-b peachtree rd.         atlanta       french (new)
# 63                 41 14th st.         atlanta            italian
# 64             126 clement st.   san francisco       french (new)
# 65          252 california st.   san francisco     american (new)
# 66               1 mission st.   san francisco     american (new)
# 67                7 claude ln.   san francisco      french bistro
# 68            340 stockton st.   san francisco     american (new)
# 69         804 north point st.   san francisco        californian
# 70              777 sutter st.   san francisco       french (new)
# 71              570 fourth st.   san francisco      french bistro
# 72            22 hawthorne st.   san francisco        californian
# 73            5937 geary blvd.   san francisco               thai
# 74               2316 polk st.   san francisco       french (new)
# 75              816 folsom st.   san francisco      mediterranean
# 76                648 bush st.   san francisco       french (new)
# 77               1737 post st.   san francisco           japanese
# 78           3127 fillmore st.   san francisco     american (new)
# 79                545 post st.   san francisco        californian
# 80            600 stockton st.   san francisco       french (new)
# 81           532 columbus ave.   san francisco            italian
#
#     pred_ref_id  pred_ref_score
# 0            31           75.00
# 1            32           88.89
# 2            33           77.78
# 3            34           88.89
# 4            35           90.00
# 5            36           91.67
# 6            37           90.00
# 7            38           90.00
# 8            39           70.00
# 9            40           81.82
# 10           41           83.33
# 11           42           80.00
# 12          780           63.64
# 13           44           77.78
# 14           45           80.00
# 15           46           90.91
# 16           47           88.89
# 17           48           66.67
# 18           49           88.89
# 19           50           77.78
# 20           51           88.89
# 21           52           90.91
# 22           53           77.78
# 23           54           88.89
# 24           55           87.50
# 25           56           88.89
# 26           57           87.50
# 27           58           90.00
# 28           59           77.78
# 29           60           77.78
# ..          ...             ...
# 52           83           75.00
# 53           84           87.50
# 54           85           88.89
# 55           86           87.50
# 56           87           90.91
# 57           88          100.00
# 58           89           72.73
# 59           90           70.00
# 60           91           72.73
# 61           92           75.00
# 62           93           71.43
# 63           94          100.00
# 64           95           88.89
# 65           96           75.00
# 66           97           87.50
# 67           98           75.00
# 68           99           88.89
# 69          100           55.56
# 70          101           90.00
# 71          102           75.00
# 72          103           85.71
# 73          104          100.00
# 74          105           88.89
# 75          106           87.50
# 76          107           87.50
# 77          108           85.71
# 78          109           66.67
# 79          110           85.71
# 80          111           80.00
# 81          112          100.00
#
# [82 rows x 7 columns]
